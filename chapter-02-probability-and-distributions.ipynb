# %% [markdown]
# # 📊 Chapter 02: Probability and Distributions
#
# You'll learn how probability helps calculate event likelihoods using real-world sales data. Furthermore, you'll explore discrete and continuous probability distributions and discover the normal distribution, a common bell-shaped curve in natural events.
#
# ## 🎲 Probability Basics
#
# - **Definition:**
#   $$
#   \text{Probability} = \frac{\text{\# of ways an event can happen}}{\text{total \# of possible outcomes}}
#   $$
# - **Examples:**
#
#   - Coin flip:
#     $$
#     P(\text{Heads}) = \frac{1}{2} = 50\%
#     $$
#   - Assigning people randomly:
#     $$
#     P(\text{Brian}) = \frac{1}{4} = 25\%
#     $$
#
# ## 🔗 Independent vs Dependent Events
#
# - **Independent Events:** One event doesn’t affect the next
#   _(e.g., flipping a coin twice)_
#
# - **Dependent Events:** One outcome affects another
#   _(e.g., drawing names without replacement)_
#
# ## 🔍 Conditional Probability
#
# - **Formula:**
#   $$
#   P(A|B) = \frac{P(A \cap B)}{P(B)}
#   $$
#
#   <div align="center">
#     <img src="./assets/orders.png" alt="orders">
#   </div>
#
# ### 🧾 Example: What is the chance of a kitchen order being over $150?
#
# - Total kitchen orders = **181**
# - Kitchen orders over $150 = **20**
#
# $$
# P(\text{Order} > 150 \mid \text{Kitchen}) = \frac{20}{181} \approx 11.05\%
# $$
#
# ### 🧾 Example: What is the chance that an order over $150 will be a kitchen product?
#
# - Orders over $150 = **601**
# - Kitchen orders over $150 = **20**
#
# $$
# P(\text{Kitchen} \mid \text{Order} > 150) = \frac{20}{601} \approx 3.33\%
# $$
#
# ## 🎲 Probability Distributions
#
# ### 📦 What is a Probability Distribution?
#
# A function that shows the likelihood of all possible outcomes.
#
# **Example:** Rolling a six-sided die:
# Each outcome (1–6) has a probability of
# $$
# \frac{1}{6}
# $$
# That’s a **discrete uniform distribution**—equal odds for all.
#
# ### 📌 Why are Probability Distributions Important?
#
# - 📊 Quantify uncertainty and risk
#
# - 🧪 Critical for hypothesis testing and inference
#
# ### 🧮 Expected Value: The Mean of a Probability Distribution
#
# Long-run average result from repeated trials.
#
# **Formula (for a fair die):**
# $$
# E = \frac{1+2+3+4+5+6}{6} = 3.5
# $$
#
# You’ll never roll a 3.5, but over many rolls, your average gets closer and closer to it.
#
# ### 🎯 Discrete Probability Distributions
#
# Used when outcomes are **countable**.
#
# **Examples:**
#
# - Coin flips
# - Dice rolls
# - Number of website visitors per day
#
# ### 📈 Law of Large Numbers
# >
# > “As your sample size grows, the sample mean approaches the expected value.”
#
# **Example:**
#
# - 10 rolls → lots of fluctuation
# - 10,000 rolls → mean hovers around 3.5
#
# ### 🌊 Continuous Probability Distributions
#
# Used when outcomes can fall **anywhere within a range** (infinite possibilities).
#
# **Examples:**
#
# - Wait time for a bus
# - Human height or weight
#
# **You calculate probabilities over a range**, not exact values:
# $$
# P(4 \leq \text{wait time} \leq 7)
# $$
#
# **Key Type:**
#
# - **Normal distribution** (the bell curve)
